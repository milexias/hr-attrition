# %% [markdown]
# # INTRODUÇÃO

# %% [markdown]
# No ambiente corporativo, a rotatividade de colaboradores representa uma diminuição inesperada na força de trabalho. Empresas com índices elevados de rotatividade de colaboradores frequentemente encaram o risco de esgotamento dos recursos internos.
#
# Este projeto elege a rotatividade de pessoal como tema central, utilizando um conjunto de dados específico com o propósito de:
#
# * Analisar os principais elementos que impactam a rotatividade de colaboradores.
# * Detectar padrões ou tendências nos dados relacionados à rotatividade de pessoal.
# * Fornecer insights acionáveis para a gestão de recursos humanos, visando à redução da rotatividade de colaboradores.
# * Elaborar e implementar medidas estratégicas para aprimorar a retenção de talentos na organização.

# %% [markdown]
# | Num | Nome das Colunas     | Dicionário das Variáveis                                                        |
# |-----|----------------------|--------------------------------------------------------------------|
# | 1   | Age                  | Idade do funcionário                                               |
# | 2   | Gender               | Gênero do funcionário                                              |
# | 3   | BusinessTravel       | Frequência de viagens a negócios dos funcionários                  |
# | 4   | DailyRate            | Salário diário dos funcionários                                    |
# | 5   | Department           | Departamento dos funcionários                                      |
# | 6   | DistanceFromHome     | Distância de casa para o trabalho em milhas                        |
# | 7   | Education            | Nível de educação alcançado pelos funcionários                     |
# | 8   | EducationField       | Área de estudo dos funcionários                                    |
# | 9   | EmployeeCount        | Número total de funcionários na organização                        |
# | 10  | EmployeeNumber       | Identificador único para cada registro de funcionário              |
# | 11  | EnvironmentSatisfaction | Satisfação do funcionário com o ambiente de trabalho            |
# | 12  | HourlyRate           | Salário por hora dos funcionários                                  |
# | 13  | JobInvolvement       | Nível de envolvimento necessário para o trabalho do funcionário    |
# | 14  | JobLevel             | Nível de trabalho do funcionário                                   |
# | 15  | JobRole              | Cargo dos funcionários na organização                              |
# | 16  | JobSatisfaction      | Satisfação do funcionário com o trabalho                           |
# | 17  | MaritalStatus        | Estado civil do funcionário                                        |
# | 18  | MonthlyIncome        | Renda mensal do funcionário                                        |
# | 19  | MonthlyRate          | Taxa salarial mensal dos funcionários                              |
# | 20  | NumCompaniesWorked   | Número de empresas para as quais o funcionário trabalhou           |
# | 21  | Over18               | Se o funcionário tem mais de 18 anos                               |
# | 22  | OverTime             | Se os funcionários trabalham horas extras                          |
# | 23  | PercentSalaryHike    | Taxa de aumento salarial para os funcionários                      |
# | 24  | PerformanceRating    | Avaliação de desempenho do funcionário                             |
# | 25  | RelationshipSatisfaction | Satisfação do funcionário com seus relacionamentos             |
# | 26  | StandardHours        | Horário padrão de trabalho para os funcionários                    |
# | 27  | StockOptionLevel     | Nível de opção de ações dos funcionários                           |
# | 28  | TotalWorkingYears    | Número total de anos que o funcionário trabalhou                   |
# | 29  | TrainingTimesLastYear | Número de vezes que os funcionários foram treinados no último ano |
# | 30  | WorkLifeBalance      | Percepção dos funcionários sobre equilíbrio entre trabalho e vida pessoal |
# | 31  | YearsAtCompany       | Número de anos que os funcionários estiveram na empresa            |
# | 32  | YearsInCurrentRole   | Número de anos que o funcionário esteve em sua função atual        |
# | 33  | YearsSinceLastPromotion | Número de anos desde a última promoção do funcionário           |
# | 34  | YearsWithCurrManager | Número de anos que um funcionário esteve com seu gerente atual     |
# | 35  | Attrition            | Se o funcionário deixou a organização                              |

# %% [markdown]
# ## IMPORTANDO AS BIBLIOTECAS

# %%
# Bibliotecas para tratar dados
import pandas as pd # data processing
import numpy as np # linear algebra

# Bibliotecas para EDA 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# Definindo o renderizador padrão como 'notebook'
import plotly.io as pio
pio.renderers.default

# Configurar para não exibir warnings
import warnings
warnings.filterwarnings("ignore")

# Configurar para exibir todas as colunas de um DataFrame do Pandas
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## IMPORTANDO OS DADOS

# %%
dados = pd.read_csv('HR-Employee-Attrition.csv', sep=';')
dados.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely       1102      Sales                 1
# 1   49        No  Travel_Frequently        279        R&D                 8
#
#            Education EducationField  EmployeeCount  EmployeeNumber  \
# 0  Associates Degree  Life Sciences              1             1.0
# 1        High School  Life Sciences              1             2.0
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
#
#               JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0     Sales Executive                4        Single           5993
# 1  Research Scientist                2       Married           5130
#
#    MonthlyRate  NumCompaniesWorked OverTime Over18  PercentSalaryHike  \
# 0        19479                   8      Yes      Y                 11
# 1        24907                   1       No      Y                 23
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7

# %% [markdown]
# Veja que os dados dizem respeito a profissionais da IBM, de diversas áreas (Department), com diversas formações (EducationField), que deixaram ou não (Attrition) a empresa.

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2925 entries, 0 to 2924
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       2925 non-null   int64
#  1   Attrition                 2925 non-null   object
#  2   BusinessTravel            2925 non-null   object
#  3   DailyRate                 2925 non-null   int64
#  4   Department                2925 non-null   object
#  5   DistanceFromHome          2925 non-null   int64
#  6   Education                 2925 non-null   object
#  7   EducationField            2925 non-null   object
#  8   EmployeeCount             2925 non-null   int64
#  9   EmployeeNumber            2924 non-null   float64
#  10  EnvironmentSatisfaction   2925 non-null   int64
#  11  Gender                    2925 non-null   object
#  12  HourlyRate                2925 non-null   int64
#  13  JobInvolvement            2925 non-null   int64
#  14  JobLevel                  2925 non-null   int64
#  15  JobRole                   2925 non-null   object
#  16  JobSatisfaction           2925 non-null   int64
#  17  MaritalStatus             2925 non-null   object
#  18  MonthlyIncome             2925 non-null   int64
#  19  MonthlyRate               2925 non-null   int64
#  20  NumCompaniesWorked        2925 non-null   int64
#  21  OverTime                  2925 non-null   object
#  22  Over18                    2925 non-null   object
#  23  PercentSalaryHike         2925 non-null   int64
#  24  PerformanceRating         2925 non-null   int64
#  25  RelationshipSatisfaction  2925 non-null   int64
#  26  StandardHours             2925 non-null   int64
#  27  StockOptionLevel          2925 non-null   int64
#  28  TotalWorkingYears         2925 non-null   int64
#  29  TrainingTimesLastYear     2925 non-null   int64
#  30  WorkLifeBalance           2925 non-null   int64
#  31  YearsAtCompany            2925 non-null   int64
#  32  YearsInCurrentRole        2925 non-null   int64
#  33  YearsSinceLastPromotion   2925 non-null   int64
#  34  YearsWithCurrManager      2925 non-null   int64
# dtypes: float64(1), int64(24), object(10)
# memory usage: 799.9+ KB

# %%
print(f"O dataframe possui {dados.shape[0]} linhas e {dados.shape[1]} colunas.")
# Out:
# O dataframe possui 2925 linhas e 35 colunas.

# %% [markdown]
# ## Limpeza dos Dados

# %%
# Vericando se possuimos dados repetidos
dados.duplicated().any()
# Out:
# False

# %%
# Removendo colunas que não iremos utilizar, portanto, não afetam o resultado final da análise

dados.drop(['EmployeeCount', 'Over18', 'StandardHours','DailyRate','HourlyRate','NumCompaniesWorked','StockOptionLevel','YearsInCurrentRole','YearsWithCurrManager','MonthlyRate'], axis=1, inplace=True)
dados.set_index('EmployeeNumber', inplace=True, drop=True)

# %%
# Verificando se possuimos dados nulos
dados.isna().values.sum()
# Out:
# 0

# %% [markdown]
# Não possuímos dados faltantes em nossos dados. E, além disso, temos bastantes colunas, de todos os tipos, para explorarmos bem os dados.

# %% [markdown]
# ## Entendendo os Dados
#
# Para uma análise explotória inicial dos dados, faremos algumas observações em variavéis númericas e categóricas.

# %%
# Colunas numéricas e método describe
numericas = dados.select_dtypes(include=('int64','float64'))

dados_describe = numericas.describe()

# Criando novas medidas dentro do describe utilizando o .loc
dados_describe.loc['amp'] = dados_describe.loc['max'] - dados_describe.loc['min'] ## amplitude dos dados
dados_describe.loc['cv'] = (dados_describe.loc['std'] / dados_describe.loc['mean']).abs() * 100 # coeficiente de variação em percentual 

# Visualizando em transpose 
dados_describe.round(2).T
# Out:
#                            count     mean      std     min     25%     50%  \
# Age                       2925.0    36.92     9.14    18.0    30.0    36.0
# DistanceFromHome          2925.0     9.17     8.09     1.0     2.0     7.0
# EnvironmentSatisfaction   2925.0     2.72     1.09     1.0     2.0     3.0
# JobInvolvement            2925.0     2.73     0.71     1.0     2.0     3.0
# JobLevel                  2925.0     2.07     1.11     1.0     1.0     2.0
# JobSatisfaction           2925.0     2.73     1.10     1.0     2.0     3.0
# MonthlyIncome             2925.0  6513.81  4713.70  1009.0  2911.0  4936.0
# PercentSalaryHike         2925.0    15.22     3.66    11.0    12.0    14.0
# PerformanceRating         2925.0     3.15     0.36     3.0     3.0     3.0
# RelationshipSatisfaction  2925.0     2.71     1.08     1.0     2.0     3.0
# TotalWorkingYears         2925.0    11.29     7.79     0.0     6.0    10.0
# TrainingTimesLastYear     2925.0     2.80     1.29     0.0     2.0     3.0
# WorkLifeBalance           2925.0     2.76     0.71     1.0     2.0     3.0
# YearsAtCompany            2925.0     7.01     6.14     0.0     3.0     5.0
# YearsSinceLastPromotion   2925.0     2.19     3.23     0.0     0.0     1.0
#
#                              75%      max      amp      cv
# Age                         43.0     60.0     42.0   24.76
# DistanceFromHome            14.0     29.0     28.0   88.20
# EnvironmentSatisfaction      4.0      4.0      3.0   40.12
# JobInvolvement               3.0      4.0      3.0   26.05
# JobLevel                     3.0      5.0      4.0   53.60
# JobSatisfaction              4.0      4.0      3.0   40.44
# MonthlyIncome             8381.0  19999.0  18990.0   72.36
# PercentSalaryHike           18.0     25.0     14.0   24.04
# PerformanceRating            3.0      4.0      1.0   11.44
# RelationshipSatisfaction     4.0      4.0      3.0   39.88
# TotalWorkingYears           15.0     40.0     40.0   69.01
# TrainingTimesLastYear        3.0      6.0      6.0   46.03
# WorkLifeBalance              3.0      4.0      3.0   25.58
# YearsAtCompany               9.0     40.0     40.0   87.47
# YearsSinceLastPromotion      3.0     15.0     15.0  147.35

# %% [markdown]
# Com o método descibre, podemos ter alguns insights sobre os dados. Como:
# - Variáveis que medem a satisfação dos funcionários possuem range de 1-4, portanto, podemos transformá-las em categóricas.
# - Além dessa, temos algumas outras variáveis que podem apresentar insights mais relevantes se transformarmos em categóricas.
# - Variação salarial bem alta em relação aos funcionários, bem como seus anos na empresa.

# %% [markdown]
# Os índices de satisfação dos funcionários são informações muito relevantes em uma análise de rotatividade de recursos internos.
# Portanto, categorizaremos de forma que facilite a compreensão visual de tais indicadores.

# %%
# Criando variaveis categóricas para auxilio da visualização

# EnvironmentSatisfaction
environment_satisfaction_mapping = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}
dados.EnvironmentSatisfaction = dados.EnvironmentSatisfaction.map(environment_satisfaction_mapping)
dados.EnvironmentSatisfaction = pd.Categorical(dados.EnvironmentSatisfaction, categories=['Low', 'Medium', 'High', 'Very High'], ordered=True)

# JobInvolvement
job_involvement_mapping = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}

dados.JobInvolvement = dados.JobInvolvement.map(job_involvement_mapping)
dados.JobInvolvement = pd.Categorical(dados.JobInvolvement, categories=['Low', 'Medium', 'High', 'Very High'], ordered=True)

# JobLevel
dados.JobLevel = pd.Categorical(dados.JobLevel, categories=[1, 2, 3, 4, 5], ordered=True)

# JobSatisfaction
job_satisfaction_mapping = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}
dados.JobSatisfaction = dados.JobSatisfaction.map(job_satisfaction_mapping)
dados.JobSatisfaction = pd.Categorical(dados.JobSatisfaction, categories=['Low', 'Medium', 'High', 'Very High'], ordered=True)

# PerformanceRating
performance_rating_mapping = {
    1: 'Low',
    2: 'Good',
    3: 'Excellent',
    4: 'Outstanding'
}
dados.PerformanceRating = dados.PerformanceRating.map(performance_rating_mapping)
dados.PerformanceRating = pd.Categorical(dados.PerformanceRating, categories=['Low', 'Good', 'Excellent', 'Outstanding'], ordered=True)

# RelationshipSatisfaction
relationship_satisfaction_mapping = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}

dados.RelationshipSatisfaction = dados.RelationshipSatisfaction.map(relationship_satisfaction_mapping)
dados.RelationshipSatisfaction = pd.Categorical(dados.RelationshipSatisfaction, categories=['Low', 'Medium', 'High', 'Very High'], ordered=True)

# WorkLifeBalance
work_life_balance_mapping = {
    1: 'Bad',
    2: 'Good',
    3: 'Better',
    4: 'Best'
}
dados.WorkLifeBalance = dados.WorkLifeBalance.map(work_life_balance_mapping)
dados.WorkLifeBalance = pd.Categorical(dados.WorkLifeBalance, categories=['Bad', 'Good', 'Better', 'Best'], ordered=True)

# Renomeando a coluna 'atrition' para o status onde 'Yes' será renomeado para 'Ex-Employee' e 'No' para 'Current Employee'
dados['Attrition'] = dados['Attrition'].replace({'Yes': 'Ex-Employee', 'No': 'Current Employee'})

# %%
# Colunas cetagoricas
categoricas = dados.select_dtypes(exclude=('int64','float64'))

# Contagem de numericas x categoricas
print(f"Temos {numericas.shape[1]} colunas numéricas e {categoricas.shape[1]} colunas categóricas.")
# Out:
# Temos 15 colunas numéricas e 16 colunas categóricas.

# %% [markdown]
# Com as devidas alterações, vamos dar uma olhada em nossas variáveis categóricas.

# %%
# Valores únicos de variáveis categoricas
for i in categoricas:
    print(f'Valores únicos:{i, set(dados[i])}')
# Out:
# Valores únicos:('Attrition', {'Current Employee', 'Ex-Employee'})
# Valores únicos:('BusinessTravel', {'Travel_Rarely', 'Travel_Frequently', 'Non-Travel'})
# Valores únicos:('Department', {'HR', 'Sales', 'R&D'})
# Valores únicos:('Education', {"Master's Degree", 'Associates Degree', "Bachelor's Degree", 'High School', 'Doctoral Degree'})
# Valores únicos:('EducationField', {'Medical', 'Other', 'Human Resources', 'Life Sciences', 'Marketing', 'Technical Degree'})
# Valores únicos:('EnvironmentSatisfaction', {'Very High', 'Low', 'Medium', 'High'})
# Valores únicos:('Gender', {'Male', 'Female'})
# Valores únicos:('JobInvolvement', {'Very High', 'Low', 'Medium', 'High'})
# Valores únicos:('JobLevel', {1, 2, 3, 4, 5})
# Valores únicos:('JobRole', {'Sales Executive', 'Manufacturing Director', 'Laboratory Technician', 'Sales Representative', 'Human Resources', 'Manager', 'Research Director', 'Healthcare Representative', 'Research Scientist'})
# Valores únicos:('JobSatisfaction', {'Very High', 'Low', 'Medium', 'High'})
# Valores únicos:('MaritalStatus', {'Single', 'Divorced', 'Married'})
# Valores únicos:('OverTime', {'Yes', 'No'})
# Valores únicos:('PerformanceRating', {'Outstanding', 'Excellent'})
# Valores únicos:('RelationshipSatisfaction', {'Very High', 'High', 'Medium', 'Low'})
# Valores únicos:('WorkLifeBalance', {'Bad', 'Better', 'Good', 'Best'})

# %% [markdown]
# # Análise Exploratória dos Dados

# %% [markdown]
# Como uma demanda no departamento de RH é uma análise de ex-funcionários e funcionários ativos, foi realizado um dashboard em PowerBi somente com a visualização de ex-funcionários.
#
# Para esta análise trabalharemos com um dataframe que representa ambos os grupos e um dataframe somente para olharmos os funcionários ativos.

# %%
# Funcionários atuais
dados_funcionarios = dados.loc[dados['Attrition'] == 'Current Employee']

# Ex-funcionários
dados_ex_funcionarios = dados.loc[dados['Attrition'] == 'Ex-Employee']

# %% [markdown]
# Na tabela abaixo obtemos uma visão agrupada dos ex-funcionários da empresa, os números destacados em verde representam grupos com a taxa superior a 5% de attrition.

# %%
# agrupamento dos dados e contagem de observações em cada grupo
frequencia = dados_ex_funcionarios.groupby(['Department', 'Gender', 'MaritalStatus']).size()

# frequência relativa em relação ao total de observações
relativa = (frequencia / frequencia.sum()) * 100

# dataframe com os resultados
df_relativa = pd.DataFrame(relativa).reset_index().rename(columns={0: 'RelativeFrequency'})

# aplicando a formatação condicional aos valores do dataframe que são superior a 5%
df_relativa_styled = df_relativa.style.applymap(
    lambda x: f'color: {"lightseagreen" if x > 5.0 else "default"}', 
    subset=pd.IndexSlice[:, 'RelativeFrequency']).format({
        'RelativeFrequency': '{:.2f} %'})

# dataframe estilizado
df_relativa_styled
# Out:
# <style type="text/css">
# #T_cee5f_row0_col3, #T_cee5f_row1_col3, #T_cee5f_row2_col3, #T_cee5f_row3_col3, #T_cee5f_row4_col3, #T_cee5f_row5_col3, #T_cee5f_row11_col3, #T_cee5f_row12_col3, #T_cee5f_row14_col3 {
#   color: default;
# }
# #T_cee5f_row6_col3, #T_cee5f_row7_col3, #T_cee5f_row8_col3, #T_cee5f_row9_col3, #T_cee5f_row10_col3, #T_cee5f_row13_col3, #T_cee5f_row15_col3, #T_cee5f_row16_col3 {
#   color: lightseagreen;
# }
# </style>
# <table id="T_cee5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cee5f_level0_col0" class="col_heading level0 col0" >Department</th>
#       <th id="T_cee5f_level0_col1" class="col_heading level0 col1" >Gender</th>
#       <th id="T_cee5f_level0_col2" class="col_heading level0 col2" >MaritalStatus</th>
#       <th id="T_cee5f_level0_col3" class="col_heading level0 col3" >RelativeFrequency</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cee5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cee5f_row0_col0" class="data row0 col0" >HR</td>
#       <td id="T_cee5f_row0_col1" class="data row0 col1" >Female</td>
#       <td id="T_cee5f_row0_col2" class="data row0 col2" >Divorced</td>
#       <td id="T_cee5f_row0_col3" class="data row0 col3" >1.22 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cee5f_row1_col0" class="data row1 col0" >HR</td>
#       <td id="T_cee5f_row1_col1" class="data row1 col1" >Female</td>
#       <td id="T_cee5f_row1_col2" class="data row1 col2" >Married</td>
#       <td id="T_cee5f_row1_col3" class="data row1 col3" >1.22 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cee5f_row2_col0" class="data row2 col0" >HR</td>
#       <td id="T_cee5f_row2_col1" class="data row2 col1" >Male</td>
#       <td id="T_cee5f_row2_col2" class="data row2 col2" >Divorced</td>
#       <td id="T_cee5f_row2_col3" class="data row2 col3" >0.81 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cee5f_row3_col0" class="data row3 col0" >HR</td>
#       <td id="T_cee5f_row3_col1" class="data row3 col1" >Male</td>
#       <td id="T_cee5f_row3_col2" class="data row3 col2" >Married</td>
#       <td id="T_cee5f_row3_col3" class="data row3 col3" >1.22 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cee5f_row4_col0" class="data row4 col0" >HR</td>
#       <td id="T_cee5f_row4_col1" class="data row4 col1" >Male</td>
#       <td id="T_cee5f_row4_col2" class="data row4 col2" >Single</td>
#       <td id="T_cee5f_row4_col3" class="data row4 col3" >0.41 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cee5f_row5_col0" class="data row5 col0" >R&D</td>
#       <td id="T_cee5f_row5_col1" class="data row5 col1" >Female</td>
#       <td id="T_cee5f_row5_col2" class="data row5 col2" >Divorced</td>
#       <td id="T_cee5f_row5_col3" class="data row5 col3" >2.03 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cee5f_row6_col0" class="data row6 col0" >R&D</td>
#       <td id="T_cee5f_row6_col1" class="data row6 col1" >Female</td>
#       <td id="T_cee5f_row6_col2" class="data row6 col2" >Married</td>
#       <td id="T_cee5f_row6_col3" class="data row6 col3" >7.72 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cee5f_row7_col0" class="data row7 col0" >R&D</td>
#       <td id="T_cee5f_row7_col1" class="data row7 col1" >Female</td>
#       <td id="T_cee5f_row7_col2" class="data row7 col2" >Single</td>
#       <td id="T_cee5f_row7_col3" class="data row7 col3" >8.94 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cee5f_row8_col0" class="data row8 col0" >R&D</td>
#       <td id="T_cee5f_row8_col1" class="data row8 col1" >Male</td>
#       <td id="T_cee5f_row8_col2" class="data row8 col2" >Divorced</td>
#       <td id="T_cee5f_row8_col3" class="data row8 col3" >6.71 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cee5f_row9_col0" class="data row9 col0" >R&D</td>
#       <td id="T_cee5f_row9_col1" class="data row9 col1" >Male</td>
#       <td id="T_cee5f_row9_col2" class="data row9 col2" >Married</td>
#       <td id="T_cee5f_row9_col3" class="data row9 col3" >13.21 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cee5f_row10_col0" class="data row10 col0" >R&D</td>
#       <td id="T_cee5f_row10_col1" class="data row10 col1" >Male</td>
#       <td id="T_cee5f_row10_col2" class="data row10 col2" >Single</td>
#       <td id="T_cee5f_row10_col3" class="data row10 col3" >18.70 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cee5f_row11_col0" class="data row11 col0" >Sales</td>
#       <td id="T_cee5f_row11_col1" class="data row11 col1" >Female</td>
#       <td id="T_cee5f_row11_col2" class="data row11 col2" >Divorced</td>
#       <td id="T_cee5f_row11_col3" class="data row11 col3" >0.81 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cee5f_row12_col0" class="data row12 col0" >Sales</td>
#       <td id="T_cee5f_row12_col1" class="data row12 col1" >Female</td>
#       <td id="T_cee5f_row12_col2" class="data row12 col2" >Married</td>
#       <td id="T_cee5f_row12_col3" class="data row12 col3" >4.27 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cee5f_row13_col0" class="data row13 col0" >Sales</td>
#       <td id="T_cee5f_row13_col1" class="data row13 col1" >Female</td>
#       <td id="T_cee5f_row13_col2" class="data row13 col2" >Single</td>
#       <td id="T_cee5f_row13_col3" class="data row13 col3" >10.37 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cee5f_row14_col0" class="data row14 col0" >Sales</td>
#       <td id="T_cee5f_row14_col1" class="data row14 col1" >Male</td>
#       <td id="T_cee5f_row14_col2" class="data row14 col2" >Divorced</td>
#       <td id="T_cee5f_row14_col3" class="data row14 col3" >3.66 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cee5f_row15_col0" class="data row15 col0" >Sales</td>
#       <td id="T_cee5f_row15_col1" class="data row15 col1" >Male</td>
#       <td id="T_cee5f_row15_col2" class="data row15 col2" >Married</td>
#       <td id="T_cee5f_row15_col3" class="data row15 col3" >7.72 %</td>
#     </tr>
#     <tr>
#       <th id="T_cee5f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cee5f_row16_col0" class="data row16 col0" >Sales</td>
#       <td id="T_cee5f_row16_col1" class="data row16 col1" >Male</td>
#       <td id="T_cee5f_row16_col2" class="data row16 col2" >Single</td>
#       <td id="T_cee5f_row16_col3" class="data row16 col3" >10.98 %</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Análise Univariada

# %%
# Criando um laço iteravél para a análise univariada de todos os dados numéricos

for column in dados.columns:
    if dados[column].dtype in ['int64', 'float64']:
        
        plt.figure(figsize=(8,4));
        sns.histplot(dados[column],kde=True,color='lightseagreen')

        plt.title(f'Histrograma da Variavél: {column}')
        plt.xlabel(column)
        plt.ylabel('Frequência')
        
        plt.grid(alpha=0)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# A análise univariada revela que a maior parte da nossa base de dados possui idades entre 25 e 40 anos.
#
# Cerca de 70% dos funcionários cadastrados residem próximo ao escritório, indicando uma distância igual ou inferior a 10.
#
# Além disso, constatamos que aproximadamente 80% dos indivíduos possuem 10 anos ou menos de experiência na empresa.

# %% [markdown]
# ## Análise Bivariada

# %% [markdown]
# Representação gráfica abordando a frequência em percentual dos funcionários ativos e dos ex-funcionários da empresa.

# %%
# Representação dos funcionários ativos e ex-funcionários 

percentual_attrition = dados['Attrition'].value_counts(normalize=True) * 100

fig = go.Figure()

# Gráfico de barras
fig.add_trace(go.Bar(
    x=percentual_attrition.index,
    y=percentual_attrition.values,
    marker_color=['thistle', 'lightseagreen'], 
    text=[f'{val:.2f}%' for val in percentual_attrition.values],  
    textposition='outside'))

# Configurando layout do gráfico
fig.update_layout(
    title='Distribuição de Funcionários e Ex-Funcionários',
    title_x=0.5,  
    title_font=dict(size=16),  
    width=1000,  
    height=500, 
    plot_bgcolor='rgba(0,0,0,0)')  

# Anotações 
fig.add_annotation(
    x=1, 
    y=percentual_attrition.mean(),
    text="<b>16%</b> dos dados representam ex-funcionários<br><b>alta taxa de rotatividade",
    showarrow=False,
    font=dict(size=12),
    align='center'
)

fig.show()
# Out:
# <div>                            <div id="76a8791b-da9d-4d11-b612-e90643d29574" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76a8791b-da9d-4d11-b612-e90643d29574")) {                    Plotly.newPlot(                        "76a8791b-da9d-4d11-b612-e90643d29574",                        [{"marker":{"color":["thistle","lightseagreen"]},"text":["83.18%","16.82%"],"textposition":"outside","x":["Current Employee","Ex-Employee"],"y":[83.17948717948718,16.82051282051282],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scatt ...

# %% [markdown]
# O gráfico acima nos mostra que 16% da nossa base de dados representam ex-funcionários, o que é considerada uma taxa alta de rotatividade.
#
# Vamos olhar os índices de satisfação dos funcionários atuais para tentarmos entender os motivos de tamanha rotatividade.

# %%
# Distribuição da Satisfação dos Funcionários

fig = go.Figure()

# Adicionando barras para funcionários atuais
fig.add_trace(go.Bar(
    x=dados_funcionarios['JobSatisfaction'].value_counts(normalize=True).index,
    y=dados_funcionarios['JobSatisfaction'].value_counts(normalize=True)*100,
    marker_color='thistle',
    name='Funcionários'
))

# Adicionando barras para ex-funcionários
fig.add_trace(go.Bar(
    x=dados_ex_funcionarios['JobSatisfaction'].value_counts(normalize=True).index,
    y=dados_ex_funcionarios['JobSatisfaction'].value_counts(normalize=True)*100,
    marker_color='lightseagreen',
    name='Ex-Funcionários'
))

# Configurando layout do gráfico
fig.update_layout(
    title='Distribuição da Satisfação Geral dos Funcionários',
    title_x=0.5,
    title_font=dict(size=16), 
    barmode='group',
    width=1000,  
    height=500, 
    plot_bgcolor='rgba(0,0,0,0)',
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="left",
        x=0.02  
    )
)

# Adicionando anotação
fig.add_annotation(
    x=2.2, 
    y=25,
    text="Mais de <b>60%</b> dos funcionários atuais<br> estão <b>satisfeitos</b> de forma geral",
    showarrow=False,
    font=dict(size=12),
    align='center'
)

# Atualizando eixo y
fig.update_yaxes(title="Em percentual (%)")

fig.show()
# Out:
# <div>                            <div id="fa347b0d-c27d-446c-b064-dd0cc39dae65" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa347b0d-c27d-446c-b064-dd0cc39dae65")) {                    Plotly.newPlot(                        "fa347b0d-c27d-446c-b064-dd0cc39dae65",                        [{"marker":{"color":"thistle"},"name":"Funcion\u00e1rios","x":["Very High","High","Medium","Low"],"y":[33.127825729551994,29.79860254829429,18.90669954788327,18.16687217427045],"type":"bar"},{"marker":{"color":"lightseagreen"},"name":"Ex-Funcion\u00e1rios","x":["High","Low","Very High","Medium"],"y":[30.691056910569102,27.235772357723576,22.5609756097561,19.51219512195122],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterp ...

# %%
# Distribuição da Satisfação dos Funcionários com o Equilíbrio de Trabalho e Vida Pessoal

fig = go.Figure()

fig.add_trace(go.Bar(
    x=dados_funcionarios['WorkLifeBalance'].value_counts(normalize=True).index,
    y=dados_funcionarios['WorkLifeBalance'].value_counts(normalize=True)*100,
    marker_color='thistle',
    name='Funcionários'
))

fig.add_trace(go.Bar(
    x=dados_ex_funcionarios['WorkLifeBalance'].value_counts(normalize=True).index,
    y=dados_ex_funcionarios['WorkLifeBalance'].value_counts(normalize=True)*100,
    marker_color='lightseagreen',
    name='Ex-Funcionários'
))

fig.update_layout(
    title='Distribuição do Equilíbrio de Trabalho e Vida Pessoal',
    title_x=0.5,  
    title_font=dict(size=16),  
    barmode='group',
    width=1000, 
    height=500,  
    plot_bgcolor='rgba(0,0,0,0)',
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="left",
        x=0.02  
    ))

fig.add_annotation(
    x=2.5, 
    y=40,
    text="Quanto ao equilíbrio de trabalho, <br>cerca de <b>80%</b> dos funcionários estão <br>nas faixas <b>intermediárias de satisfação",
    showarrow=False,
    font=dict(size=12),
    align='center'
)

fig.update_yaxes(title="Em percentual (%)") # atualizando eixo y

fig.show()
# Out:
# <div>                            <div id="3b17a150-644c-4913-bdea-2f760ff01e3b" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b17a150-644c-4913-bdea-2f760ff01e3b")) {                    Plotly.newPlot(                        "3b17a150-644c-4913-bdea-2f760ff01e3b",                        [{"marker":{"color":"thistle"},"name":"Funcion\u00e1rios","x":["Better","Good","Best","Bad"],"y":[62.104397862720916,23.01685162351007,10.35758323057953,4.521167283189477],"type":"bar"},{"marker":{"color":"lightseagreen"},"name":"Ex-Funcion\u00e1rios","x":["Better","Good","Best","Bad"],"y":[54.0650406504065,25.0,10.975609756097562,9.959349593495935],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterp ...

# %%
# Distribuição da Satisfação dos Funcionários  com o Ambiente de Trabalho

fig = go.Figure()

fig.add_trace(go.Bar(
    x=dados_funcionarios['EnvironmentSatisfaction'].value_counts(normalize=True).index,
    y=dados_funcionarios['EnvironmentSatisfaction'].value_counts(normalize=True)*100,
    marker_color='thistle',
    name='Funcionários'
))

fig.add_trace(go.Bar(
    x=dados_ex_funcionarios['EnvironmentSatisfaction'].value_counts(normalize=True).index,
    y=dados_ex_funcionarios['EnvironmentSatisfaction'].value_counts(normalize=True)*100,
    marker_color='lightseagreen',
    name='Ex-Funcionários'
))

fig.update_layout(
    title='Distribuição da Satisfação com o Ambiente de Trabalho',
    title_x=0.5,  
    title_font=dict(size=16), 
    barmode='group',
    width=1000,  
    height=500,
    plot_bgcolor='rgba(0,0,0,0)',
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="left",
        x=0.02  
    ))

fig.add_annotation(
    x=2.2, 
    y=30,
    text="A <b>satisfação</b> com o ambiente de trabalho<br>abrange <b>60%</b> e aumenta os <br>funcionários <b>muito satisfeitos",
    showarrow=False,
    font=dict(size=12),
    align='center'
)

fig.update_yaxes(title="Em percentual (%)")

fig.show()
# Out:
# <div>                            <div id="c6ba589d-1ab3-4976-b7fd-afe830f49ca9" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6ba589d-1ab3-4976-b7fd-afe830f49ca9")) {                    Plotly.newPlot(                        "c6ba589d-1ab3-4976-b7fd-afe830f49ca9",                        [{"marker":{"color":"thistle"},"name":"Funcion\u00e1rios","x":["High","Very High","Medium","Low"],"y":[31.89478010686395,31.237155774763664,19.893136046033703,16.974928072338678],"type":"bar"},{"marker":{"color":"lightseagreen"},"name":"Ex-Funcion\u00e1rios","x":["Low","High","Very High","Medium"],"y":[30.691056910569102,26.01626016260163,25.609756097560975,17.682926829268293],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scat ...

# %%
# Distribuição da treinamentos realizados no último ano

fig = go.Figure()

fig.add_trace(go.Bar(
    x=dados_funcionarios['TrainingTimesLastYear'].value_counts(normalize=True).index,
    y=dados_funcionarios['TrainingTimesLastYear'].value_counts(normalize=True)*100,
    marker_color='thistle',
    name='Funcionários'
))

fig.add_trace(go.Bar(
    x=dados_ex_funcionarios['TrainingTimesLastYear'].value_counts(normalize=True).index,
    y=dados_ex_funcionarios['TrainingTimesLastYear'].value_counts(normalize=True)*100,
    marker_color='lightseagreen',
    name='Ex-Funcionários'
))

fig.update_layout(
    title='Distribuição por Número de Treinamentos no Último Ano',
    title_x=0.5, 
    title_font=dict(size=16),  
    barmode='group',
    width=1000,
    height=500, 
    plot_bgcolor='rgba(0,0,0,0)',
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="left",
        x=0.02  
))

fig.add_annotation(
    x=5.3, 
    y=30,
    text="Com o <b>aumento de treinamentos</b>,<br>a representatividade de <b>ex-funcionários <br>declina</b> consideravelmente.",
    showarrow=False,
    font=dict(size=12),
    align='center')

fig.update_yaxes(title="Em percentual (%)")

fig.show()
# Out:
# <div>                            <div id="ed3a8270-0a32-47c7-9f85-0464f0ceb3f1" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed3a8270-0a32-47c7-9f85-0464f0ceb3f1")) {                    Plotly.newPlot(                        "ed3a8270-0a32-47c7-9f85-0464f0ceb3f1",                        [{"marker":{"color":"thistle"},"name":"Funcion\u00e1rios","x":[2,3,5,4,1,6,0],"y":[36.53925195232224,34.1553637484587,8.425811755034935,7.93259350595972,4.932182490752158,4.808877928483354,3.2059186189889024],"type":"bar"},{"marker":{"color":"lightseagreen"},"name":"Ex-Funcion\u00e1rios","x":[2,3,4,5,0,1,6],"y":[41.260162601626014,29.268292682926827,10.569105691056912,6.300813008130081,5.894308943089431,4.0650406504065035,2.642276422764228],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scatte ...

# %%
# Distribuição da treinamentos realizados no último ano

fig = go.Figure()

fig.add_trace(go.Bar(
    x=dados_funcionarios['BusinessTravel'].value_counts(normalize=True).index,
    y=dados_funcionarios['BusinessTravel'].value_counts(normalize=True)*100,
    marker_color='thistle',
    name='Funcionários'
))

fig.add_trace(go.Bar(
    x=dados_ex_funcionarios['BusinessTravel'].value_counts(normalize=True).index,
    y=dados_ex_funcionarios['BusinessTravel'].value_counts(normalize=True)*100,
    marker_color='lightseagreen',
    name='Ex-Funcionários'
))

fig.update_layout(
    title='Distribuição por Viagens a Trabalho',
    title_x=0.5, 
    title_font=dict(size=16),  
    barmode='group',
    width=1000,
    height=500, 
    plot_bgcolor='rgba(0,0,0,0)',
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="left",
        x=0.02  
))

fig.add_annotation(
    x=2, 
    y=40,
    text="A taxa de funcionários que <b>viaja frequentemente</b><br> possui maior representatividade de <b>ex-funcionários",
    showarrow=False,
    font=dict(size=12),
    align='center')

fig.update_yaxes(title="Em percentual (%)")

fig.show()
# Out:
# <div>                            <div id="91c7ddd7-6378-45da-a2ec-d4e6f13b17ce" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91c7ddd7-6378-45da-a2ec-d4e6f13b17ce")) {                    Plotly.newPlot(                        "91c7ddd7-6378-45da-a2ec-d4e6f13b17ce",                        [{"marker":{"color":"thistle"},"name":"Funcion\u00e1rios","x":["Travel_Rarely","Travel_Frequently","Non-Travel"],"y":[71.92766132346897,16.810521989313603,11.261816687217427],"type":"bar"},{"marker":{"color":"lightseagreen"},"name":"Ex-Funcion\u00e1rios","x":["Travel_Rarely","Travel_Frequently","Non-Travel"],"y":[66.05691056910568,28.65853658536585,5.284552845528456],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar": ...

# %%
# Distribuição de MaritalStatus

fig = go.Figure()

fig.add_trace(go.Bar(
    x=dados_funcionarios['MaritalStatus'].value_counts(normalize=True).index,
    y=dados_funcionarios['MaritalStatus'].value_counts(normalize=True)*100,
    marker_color='thistle',
    name='Funcionários'
))

fig.add_trace(go.Bar(
    x=dados_ex_funcionarios['MaritalStatus'].value_counts(normalize=True).index,
    y=dados_ex_funcionarios['MaritalStatus'].value_counts(normalize=True)*100,
    marker_color='lightseagreen',
    name='Ex-Funcionários'
))

fig.update_layout(
    title='Distribuição por Estado Civil',
    title_x=0.5, 
    title_font=dict(size=16),  
    barmode='group',
    width=1000,
    height=500, 
    plot_bgcolor='rgba(0,0,0,0)',
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="left",
        x=0.02  
))

fig.add_annotation(
    x=2, 
    y=35,
    text="<b>50%</b> dos ex-funcionários são solteiros</b><br>em contraponto <b><br>50%</b> dos funcionários atuais são casados",
    showarrow=False,
    font=dict(size=12),
    align='center')

fig.update_yaxes(title="Em percentual (%)")

fig.show()
# Out:
# <div>                            <div id="d00bdabb-ac56-4ad1-a956-92430d3424f0" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d00bdabb-ac56-4ad1-a956-92430d3424f0")) {                    Plotly.newPlot(                        "d00bdabb-ac56-4ad1-a956-92430d3424f0",                        [{"marker":{"color":"thistle"},"name":"Funcion\u00e1rios","x":["Married","Single","Divorced"],"y":[47.924373201808464,28.401150842581174,23.674475955610358],"type":"bar"},{"marker":{"color":"lightseagreen"},"name":"Ex-Funcion\u00e1rios","x":["Single","Married","Divorced"],"y":[49.390243902439025,35.36585365853659,15.24390243902439],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"c ...

# %%
# Distribuição de MaritalStatus

fig = go.Figure()

fig.add_trace(go.Bar(
    x=dados_funcionarios['Department'].value_counts(normalize=True).index,
    y=dados_funcionarios['Department'].value_counts(normalize=True)*100,
    marker_color='thistle',
    name='Funcionários'
))

fig.add_trace(go.Bar(
    x=dados_ex_funcionarios['Department'].value_counts(normalize=True).index,
    y=dados_ex_funcionarios['Department'].value_counts(normalize=True)*100,
    marker_color='lightseagreen',
    name='Ex-Funcionários'
))

fig.update_layout(
    title='Distribuição por Departamento',
    title_x=0.5, 
    title_font=dict(size=16),  
    barmode='group',
    width=1000,
    height=500, 
    plot_bgcolor='rgba(0,0,0,0)',
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=1.02,
        xanchor="left",
        x=0.02  
))

fig.add_annotation(
    x=2, 
    y=35,
    text="O departamento <b>Resarch & Devolopment</b><br>representa em torno de <b>60%</b> dos funcionários",
    showarrow=False,
    font=dict(size=12),
    align='center')

fig.update_yaxes(title="Em percentual (%)")

fig.show()
# Out:
# <div>                            <div id="512a2a2c-ceb3-443e-a686-7a626d5304b4" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("512a2a2c-ceb3-443e-a686-7a626d5304b4")) {                    Plotly.newPlot(                        "512a2a2c-ceb3-443e-a686-7a626d5304b4",                        [{"marker":{"color":"thistle"},"name":"Funcion\u00e1rios","x":["R&D","Sales","HR"],"y":[66.7488697081792,29.05877517468146,4.192355117139334],"type":"bar"},{"marker":{"color":"lightseagreen"},"name":"Ex-Funcion\u00e1rios","x":["R&D","Sales","HR"],"y":[57.3170731707317,37.80487804878049,4.878048780487805],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0," ...

# %% [markdown]
# Quanto as análises univariadas, podemos perceber um baixo índice de satisfação dos funcionários atuais. Sendo a opção 'dissatisfied' a com maior frequência nos índices.
#
# Em alguns indicadores, os funcionários estão mais insatisfeitos do que funcionários que deixaram a empresa.
#
# Além disso, o aumento de treinamentos declina a quantidade de ex-funcionários consideravelmente. Investir em treinamentos pode ser uma boa estratégia para retenção de talentos.

# %% [markdown]
# ### Análise com Indicadores de Rendas

# %%
# Funil de renda para a média salarial por Nível de Educação

income_education = dados_funcionarios.groupby('Education')['MonthlyIncome'].mean().reset_index()

income_education = income_education.sort_values(by='MonthlyIncome', ascending=False).round()

fig = go.Figure()

fig = px.funnel(income_education, 
             x='MonthlyIncome', 
             y='Education',
             color_discrete_sequence=['lightseagreen'])  

fig.update_layout(
    title='Renda Média por Nível de Educação',
    xaxis_title='',  
    yaxis_title='', 
    plot_bgcolor='rgba(0,0,0,0)',
    width=900, 
    height=500,
    title_x=0.5
    )

fig.show()
# Out:
# <div>                            <div id="98b11511-e2d7-4ea1-9625-619ea25d524a" class="plotly-graph-div" style="height:500px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98b11511-e2d7-4ea1-9625-619ea25d524a")) {                    Plotly.newPlot(                        "98b11511-e2d7-4ea1-9625-619ea25d524a",                        [{"hovertemplate":"MonthlyIncome=%{x}<br>Education=%{y}<extra></extra>","legendgroup":"","marker":{"color":"lightseagreen"},"name":"","orientation":"h","showlegend":false,"x":[8560.0,7072.0,6902.0,6667.0,5993.0],"xaxis":"x","y":["Doctoral Degree","Master's Degree","Bachelor's Degree","Associates Degree","High School"],"yaxis":"y","type":"funnel"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"c ...

# %% [markdown]
# A variação de salário médio apresenta uma crescida proporcional ao aumento do nível de educação.

# %%
# Violino e boxplots para a distribuição de Renda por Gênero

fig = go.Figure()

fig = px.violin(dados_funcionarios, 
             x='Gender', 
             y='MonthlyIncome', 
             color='Gender',
             color_discrete_map={'Male': 'lightskyblue', 'Female': 'thistle'},
             box=True) # boxplot dentro do violino

# Personalizando o layout do gráfico
fig.update_layout(
    title='Distribuição de Renda por Gênero',
    yaxis_title='Renda Mensal',
    xaxis_title='',
    plot_bgcolor='rgba(0,0,0,0)',
    width=1000, 
    height=500,
    title_x=0.5,
    showlegend=False)

fig.show()
# Out:
# <div>                            <div id="54312643-e4e3-4819-b431-776280e15797" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54312643-e4e3-4819-b431-776280e15797")) {                    Plotly.newPlot(                        "54312643-e4e3-4819-b431-776280e15797",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Gender=%{x}<br>MonthlyIncome=%{y}<extra></extra>","legendgroup":"Male","marker":{"color":"lightskyblue"},"name":"Male","offsetgroup":"Male","orientation":"v","scalegroup":"True","showlegend":true,"x":["Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","M ...

# %% [markdown]
# A distribuição salarial é bem equiparada entre os sexos.

# %%
# Boxplot para a distribuição de Renda por Gênero

fig = go.Figure()

cores_departamentos = {
    'Life Sciences':'turquoise', 'Other':'turquoise', 'Marketing':'turquoise', 'Medical':'turquoise',
    'Technical Degree': 'turquoise', 'Human Resources':'darkcyan' }

fig = px.box(dados_funcionarios,
             x="EducationField",
             y="MonthlyIncome",
             color="EducationField",
             color_discrete_map=cores_departamentos)  

fig.update_layout(
    title="Distribuição de Renda por Área de Estudos",
    xaxis_title="Área de Estudos",
    yaxis_title="Renda",
    plot_bgcolor='rgba(0,0,0,0)', 
    width=1000, 
    height=500,
    title_x=0.5,
    showlegend=False)

fig.show()
# Out:
# <div>                            <div id="9542f1c3-5849-421d-9108-cff892ffe48b" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9542f1c3-5849-421d-9108-cff892ffe48b")) {                    Plotly.newPlot(                        "9542f1c3-5849-421d-9108-cff892ffe48b",                        [{"alignmentgroup":"True","hovertemplate":"EducationField=%{x}<br>MonthlyIncome=%{y}<extra></extra>","legendgroup":"Life Sciences","marker":{"color":"turquoise"},"name":"Life Sciences","notched":false,"offsetgroup":"Life Sciences","orientation":"v","showlegend":true,"x":["Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Scienc ...

# %% [markdown]
# Os funcionários que estão na área de Recursos Humanos possuem a maior variação salarial perante aos demais setores.

# %%
# Distribuição de Renda por Departamento

cores_departamentos = {
    'HR': 'darkcyan',
    'R&D': 'thistle',
    'Sales': 'lightsalmon'}

fig = go.Figure()

fig = px.box(dados_funcionarios,
             x="Department",
             y="MonthlyIncome",
             color="Department",
             color_discrete_map=cores_departamentos)

fig.update_layout(
    title="Distribuição de Renda por Departamento",
    xaxis_title="Departamento",
    yaxis_title="Renda",
    plot_bgcolor='rgba(0,0,0,0)',  
    width=1000, 
    height=500,
    title_x=0.5,
    showlegend=False)

fig.show()
# Out:
# <div>                            <div id="db546781-874b-4f32-ab48-d7854cae3a53" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db546781-874b-4f32-ab48-d7854cae3a53")) {                    Plotly.newPlot(                        "db546781-874b-4f32-ab48-d7854cae3a53",                        [{"alignmentgroup":"True","hovertemplate":"Department=%{x}<br>MonthlyIncome=%{y}<extra></extra>","legendgroup":"R&D","marker":{"color":"thistle"},"name":"R&D","notched":false,"offsetgroup":"R&D","orientation":"v","showlegend":true,"x":["R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D","R&D ...

# %%
# Distribuição realizando a comparação de idades dos funcionários e anos de trabalho

fig = go.Figure()

fig = px.scatter(dados_funcionarios, 
                 x="Age", 
                 y="TotalWorkingYears", 
                 color="Department",
                 color_discrete_map=cores_departamentos,
                 size='TotalWorkingYears',
                 hover_name='EducationField',log_x=True) 

# Personalizando o layout do gráfico
fig.update_layout(
    title="Idade vs Anos de Trabalho",
    xaxis_title="Idade",
    yaxis_title="Anos de Trabalho",
    plot_bgcolor='rgba(0,0,0,0)',  # Cor de fundo do gráfico
    width=1000, 
    height=500,
    title_x=0.5)

fig.show()
# Out:
# <div>                            <div id="08667e1e-569f-404e-815a-1e4e3d8aa1f9" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08667e1e-569f-404e-815a-1e4e3d8aa1f9")) {                    Plotly.newPlot(                        "08667e1e-569f-404e-815a-1e4e3d8aa1f9",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Department=R&D<br>Age=%{x}<br>TotalWorkingYears=%{marker.size}<extra></extra>","hovertext":["Life Sciences","Other","Medical","Medical","Other","Medical","Medical","Life Sciences","Other","Life Sciences","Medical","Life Sciences","Life Sciences","Medical","Life Sciences","Medical","Life Sciences","Life Sciences","Medical","Life Sciences","Medical","Technical Degree","Medical","Life Sciences","Life Sciences","Medical","Life Sciences","Medical","Life Sciences","Life Sciences","Life Sciences","Other","Medical","Life Sciences","Medical","Medical","Medical","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Medical","Technical Degree","Medical","Life Sciences","Other","Life Sciences","Life Sciences","Medical","Medical","Medical","Life Sciences","Life Sciences","Medical","Life Sciences","Life Sciences","Life Sciences","Other","Technical Degree","Medical","Medical","Medical","Medical","Technical Degree","Life Sciences","Technical Degree","Medical","Life Sciences","Life Sciences","Medical","Medical","Life Sciences","Technical Degree","Medical","Medical","Medical","Medical","Medical","Life Sciences","Medical","Life Sciences","Life Sciences","Life Sciences","Technical Degree","Medical","Medical","Life Sciences","Life Sciences","Life Sciences","Medical","Medical","Medical","Medical","Medical","Medical","Medical","Life Sciences","Medical","Life Sciences","Medical","Medical","Medical","Life Sciences","Medical","Medical","Life Sciences","Technical Degree","Technical Degree","Life Sciences","Medical","Medical","Life Sciences","Medical","Life Sciences","Medical","Life Sciences","Life Sciences","Life Sciences","Medical","Other","Medical","Life Sciences","Life Sciences","Technical Degree","Medical","Life Sciences","Technical Degree","Other","Medical","Life Sciences","Life Sciences","Medical","Life Sciences","Technical Degree","Life Sciences","Life Sciences","Life Sciences","Medical","Medical","Life Sciences","Life Sciences","Technical Degree","Medical","Life Sciences","Medical","Life Sciences","Medical","Medical","Medical","Medical","Life Sciences","Life Sciences","Life Sciences","Medical","Technical Degree","Medical","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Technical Degree","Medical","Life Sciences","Medical","Medical","Medical","Life Sciences","Life Sciences","Life Sciences","Technical Degree","Life Sciences","Life Sciences","Life Sciences","Medical","Life Sciences","Technical Degree","Life Sciences","Medical","Medical","Life Sciences","Medical","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Other","Other","Medical","Life Sciences","Medical","Technical Degree","Life Sciences","Medical","Life Sciences","Medical","Medical","Other","Medical","Life Sciences","Medical","Medical","Technical Degree","Life Sciences","Life Sciences","Life Sciences","Medical","Other","Life Sciences","Life Sciences","Medical","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Medical","Medical","Medical","Medical","Other","Medical","Life Sciences","Life Sciences","Medical","Medical","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Medical","Technical Degree","Life Sciences","Life Sciences","Life Sciences","Medical","Life Sciences","Medical","Medical","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Life Sciences","Other","Life Sciences","Life Sciences","Medical","Technic ...

# %% [markdown]
# Os profissionais do departamento de Vendas possuem a distribuição bem ampla, entretanto, são os profissionais com a maior representatividade na faixa até 45 anos.
#
# Enquanto o departamento de Research & Development são os profissionais que possuem mais representação em faixas etarias +45 anos.

# %%
# Histograma da Idade dos Funcionários

fig = go.Figure()

# dados do histograma
media_idade = dados_funcionarios['Age'].mean()
data = [go.Histogram(x=dados_funcionarios.Age, 
                     nbinsx=20, 
                     marker=dict(color='thistle'),
                     showlegend=False)]  

# linha da media
line = [go.Scatter(x=[media_idade, media_idade], 
                   y=[0,527], 
                   mode='lines',
                   line=dict(color='lightseagreen', dash='dash'), 
                   showlegend=True,
                   name=f"Media = {media_idade:.2f}")]

fig = go.Figure(data=data+line)

fig.update_layout(title='Histograma da Idade dos Funcionários', 
                  xaxis_title='Idade',
                  yaxis_title='Contagem',
                  autosize=False, 
                  plot_bgcolor='rgba(0,0,0,0)',
                  width=1000, 
                  height=500,
                  title_x=0.5)

fig.show()
# Out:
# <div>                            <div id="cfe67fa5-104f-4552-827d-7795e3fbdacb" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfe67fa5-104f-4552-827d-7795e3fbdacb")) {                    Plotly.newPlot(                        "cfe67fa5-104f-4552-827d-7795e3fbdacb",                        [{"marker":{"color":"thistle"},"nbinsx":20,"showlegend":false,"x":[49,53,42,44,46,33,44,30,43,35,36,33,35,27,27,30,34,37,46,35,44,35,26,33,35,35,31,37,32,38,50,59,36,55,36,45,35,59,29,31,32,36,31,35,45,37,46,30,35,55,38,34,56,23,51,30,40,51,30,46,32,54,24,28,58,44,32,34,37,59,50,25,22,51,54,24,34,37,34,36,36,43,30,33,51,26,22,49,43,50,41,26,36,39,25,30,45,38,30,32,30,30,41,41,19,40,35,53,45,32,29,51,58,40,34,22,27,28,57,27,50,41,30,38,32,27,36,30,45,56,33,46,38,31,34,50,53,33,40,55,34,51,52,27,43,45,37,35,42,38,38,27,49,34,40,22,36,40,46,30,27,51,41,45,54,36,33,37,38,31,59,37,29,35,52,42,59,50,43,52,32,39,32,41,40,45,31,33,34,37,45,39,29,42,29,25,42,40,51,32,38,32,46,29,31,25,45,36,55,28,37,21,37,35,38,26,50,53,42,29,55,26,37,38,28,49,36,31,37,42,35,36,51,41,18,28,31,39,36,32,38,58,31,31,45,31,33,39,43,49,27,32,27,31,32,30,31,39,33,47,43,27,54,43,45,40,29,30,27,37,38,31,29,35,23,41,47,42,29,42,32,48,37,30,26,42,36,36,57,40,21,37,46,50,31,29,35,27,28,49,51,36,55,24,30,22,36,37,40,42,37,43,40,54,34,31,43,43,25,37,31,39,56,30,41,28,52,45,52,42,30,60,46,42,38,40,26,30,29,30,57,50,30,60,47,46,35,54,34,46,31,30,35,42,36,48,55,41,35,40,39,31,42,45,29,33,31,40,41,26,35,34,37,46,41,37,52,24,38,37,49,24,26,24,50,25,34,35,31,27,37,20,42,43,38,43,48,44,34,21,44,22,33,32,30,53,34,26,37,29,35,33,54,36,27,35,23,25,38,29,48,27,37,50,34,39,32,38,27,32,47,40,53,41,60,27,41,50,36,38,44,47,30,29,43,34,23,39,56,40,27,29,53,35,32,38,34,52,25,45,23,34,36,52,26,29,34,54,27,37,38,34,35,30,40,34,42,24,52,50,33,47,36,29,35,42,36,32,40,30,45,42,38,34,43,27,35,28,34,27,51,44,25,33,35,36,32,30,53,45,32,52,37,28,22,44,42,36,25,35,32,25,49,24,32,38,42,31,53,35,37,53,43,47,37,50,39,33,29,44,28,43,36,47,28,27,34,42,33,58,31,35,49,48,31,36,38,32,40,26,41,36,31,40,32,33,45,29,35,52,53,30,38,35,39,47,36,33,33,45,50,33,41,27,45,47,50,38,46,24,31,18,54,35,30,26,22,48,48,41,39,27,35,42,50,59,55,41,38,44,50,39,33,45,32,34,59,45,53,34,28,38,50,37,40,26,46,54,56,36,55,43,46,26,30,41,38,40,27,55,28,33,28,34,37,42,33,34,48,45,52,38,29,28,46,38,43,40,21,39,36,31,28,35,49,34,29,42,29,38,28,41,37,27,34,35,40,42,35,24,26,30,40,35,34,35,32,56,29,19,45,37,20,53,29,46,44,33,30,40,50,28,46,35,33,36,30,44,20,46,42,60,32,32,36,33,40,25,30,42,35,27,54,44,29,54,31,31,59,43,49,36,48,27,29,48,29,34,44,33,19,23,26,55,46,34,51,59,34,28,44,34,35,42,43,36,28,51,30,28,25,32,45,39,58,30,36,46,28,50,30,39,31,41,42,55,56,40,34,40,41,35,51,38,34,25,40,36,48,27,51,18,35,27,56,34,40,34,38,34,28,39,51,41,37,33,32,39,25,52,43,27,26,42,32,36,35,47,18,39,24,33,48,36,38,27,40,29,39,42,30,44,31,25,47,31,31,40,40,29,34,45,50,33,43,51,34,27,52,38,37,29,35,40,49,48,34,32,38,38,29,54,40,49,54,47,45,36,32,40,31,37,30,39,47,32,23,27,29,35,45,54,46,48,30,47,38,36,39,40,28,46,56,40,31,36,31,36,32,27,38,36,20,36,34,26,45,49,28,38,41,35,40,30,40,33,33,47,32,43,31,32,44,28,37,42,39,52,45,47,46,38,24,29,34,34,34,25,49,29,38,32,26,36,34,38,45,35,27,39,37,49,33,28,31,32,37,29,29,43,55,28,40,31,39,40,46,43,38,55,49,29,27,32,45,24,24,39,42,37,27,35,34,53,48,30,29,49,43,25,47,35,30,34,27,31,30,34,44,42,35,42,28,30,24,39,44,35,33,23,36,40,42,35,28,29,39,33,55,37,26,36,36,23,34,39,24,35,41,40,26,46,49,21,26,35,33,29,32,44,42,22,23,53,31,30,41,34,29,33,48,40,33,31,31,32,35,30,38,32,35,32,39,37,36,38,30,38,39,40,33,29,26,34,20,28,41,27,46,22,38,24,27,44,35,44,47,49,31,35,26,40,33,49,44,38,36,35,45,54,40,41,31,35,34,36,47,58,24,36,40,31,39,34,44,38,58,34,36,50,42,35,35,44,50,29,28,55,45,46,42,25,41,55 ...

# %% [markdown]
# A média dos funcionários apresenta uma distribuição normal, com a média de funcionários de 38 anos.

# %% [markdown]
# ## Matriz de Correlação e Dispersão dos Dados

# %%
# Calculo da matriz de correlação
corr = numericas.corr()

sns.set_style("whitegrid")

# mask para esconder a metade superior da matriz de correlação
mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(10, 8))

# mapa de calor em percentual
sns.heatmap(corr, mask=mask, cmap="crest", vmax=.7, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8},
            annot=True, fmt=".0%")

plt.title('Matriz de Correlação (em %)',fontsize=14)

plt.grid(alpha=0)

plt.show()

# %% [markdown]
# A maior correlação encontrada foi:
# - MonthlyIncome (renda mensal) vs JobLevel (nível de trabalho).
#
# Entretanto, algumas outras variaveis possuem uma relação forte, como:
# - TotalWorkingYears (anos de trabalho) vs JobLevel (nível de trabalho)
# - PerformanceRating (desempenho do funcionário) vs PercentSalaryHike (taxa de aumento salarial)
# - TotalWorkingYears (anos de trabalho) vs MonthlyIncome (renda mensal)

# %%
# Gráficos com as maiores correlações representados por uma regressão linear

sns.set_style("whitegrid")

fig, axs = plt.subplots(1, 3, figsize=(26, 8))

# gráfico de regressão para JobLevel vs. MonthlyIncome
sns.regplot(x="JobLevel", y="MonthlyIncome", data=dados_funcionarios, ax=axs[0],color='lightseagreen')
axs[0].set_xlabel("JobLevel", fontsize=14)
axs[0].set_ylabel("MonthlyIncome", fontsize=14)
axs[0].xaxis.grid(False)  # Removendo as grades no eixo x
axs[0].yaxis.grid(False)  # Removendo as grades no eixo y

# gráfico de regressão para YearsAtCompany vs. MonthlyIncome
sns.regplot(x="TotalWorkingYears", y="MonthlyIncome", data=dados_funcionarios, ax=axs[1],color='lightseagreen')
axs[1].set_xlabel("TotalWorkingYears", fontsize=14)
axs[1].set_ylabel("MonthlyIncome", fontsize=14)
axs[1].xaxis.grid(False)  # Removendo as grades no eixo x
axs[1].yaxis.grid(False)  # Removendo as grades no eixo y

# gráfico de regressão para JobLevel vs. TotalWorkingYears
sns.regplot(x="JobLevel", y="TotalWorkingYears", data=dados_funcionarios, ax=axs[2],color='lightseagreen')
axs[2].set_xlabel("JobLevel", fontsize=14)
axs[2].set_ylabel("TotalWorkingYears", fontsize=14)
axs[2].xaxis.grid(False)  # Removendo as grades no eixo x
axs[2].yaxis.grid(False)  # Removendo as grades no eixo y

fig.suptitle("Gráficos de Regressão Linear", fontsize=14)

plt.show()

# %% [markdown]
# Fonte de dados: [Kaggle](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset/data)
